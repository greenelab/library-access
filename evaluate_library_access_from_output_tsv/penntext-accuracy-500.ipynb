# %% [markdown]
# # Library Access PennText Accuracy Analysis on 500 random DOIs
#
# https://github.com/greenelab/library-access

# %%
import pathlib

import pandas
from statsmodels.stats.proportion import proportion_confint

# %%
formatter = '{:.1%}'.format

# %%
manual_df = pandas.read_table('manual-doi-checks-500.tsv')
manual_df['penntext_correct'] = (manual_df.penntext == manual_df.penn_access).astype(int)
manual_df.head(2)
# Out:
#                          doi  penntext  penn_access  open_access  \
# 0         10.1007/bf01441062         0            0            0
# 1  10.20531/tfb.2016.44.1.11         0            1            1
#
#   penn_access_date open_access_date  penntext_correct
# 0       2018-01-04       2018-01-04                 1
# 1       2018-01-04       2018-01-04                 0

# %% [markdown]
# ## Summarizing manual access

# %%
assert manual_df.query("open_access == 1").penn_access.all()
pandas.crosstab(manual_df.open_access, manual_df.penn_access, margins=True)
# Out:
# penn_access   0    1  All
# open_access
# 0            63  263  326
# 1             0  174  174
# All          63  437  500

# %%
manual_df[['penntext', 'open_access', 'penn_access', 'penntext_correct']].mean().map(formatter)
# Out:
# penntext            84.4%
# open_access         34.8%
# penn_access         87.4%
# penntext_correct    88.2%
# dtype: object

# %%
def get_confidence_interval(x, alpha=0.05):
    """
    Compute a confidence interval for a binomial proportion.
    x is a list of observations, coded as 0/1.
    Uses Jeffreys method described in
    - https://doi.org/10.1214/ss/1009213286
    - https://doi.org/10.2307/271031
    """
    confint = proportion_confint(
        count=sum(x),
        nobs=len(x),
        alpha=alpha,
        method='jeffreys',
    )
    return '{:.1%}–{:.1%}'.format(*confint)

# %%
manual_df[['penntext', 'open_access', 'penn_access', 'penntext_correct']].apply(get_confidence_interval)
# Out:
# penntext            81.0%–87.4%
# open_access         30.7%–39.1%
# penn_access         84.3%–90.1%
# penntext_correct    85.2%–90.8%
# dtype: object

# %% [markdown]
# ## PennText accuracy

# %%
def summarize(df):
    row = pandas.Series()
    row['n_articles'] = len(df)
    row['n_penntext_correct'] = df.penntext_correct.sum()
    row['penntext_accuracy'] = formatter(df.penntext_correct.mean())
    row['penntext_accuracy_ci'] = get_confidence_interval(df.penntext_correct)
    return row

def summarize_by_columns(df, columns):
    """
    Group df by columns and calculate penntext accuracy for each group.
    """
    columns = list(columns)
    summary_df = manual_df.groupby(columns).apply(summarize).reset_index()
    for column in 'n_articles', 'n_penntext_correct':
        summary_df[column] = summary_df[column].astype(int)
    return summary_df

# %%
# Overall PennText accuracy
summarize(manual_df)
# Out:
# n_articles                      500
# n_penntext_correct              441
# penntext_accuracy             88.2%
# penntext_accuracy_ci    85.2%–90.8%
# dtype: object

# %%
# Accuracy within open access category
summarize_by_columns(manual_df, ['open_access'])
# Out:
#    open_access  n_articles  n_penntext_correct penntext_accuracy  \
# 0            0         326                 290             89.0%
# 1            1         174                 151             86.8%
#
#   penntext_accuracy_ci
# 0          85.2%–92.0%
# 1          81.2%–91.2%

# %%
# Accuracy within penn access category
summarize_by_columns(manual_df, ['penn_access'])
# Out:
#    penn_access  n_articles  n_penntext_correct penntext_accuracy  \
# 0            0          63                  41             65.1%
# 1            1         437                 400             91.5%
#
#   penntext_accuracy_ci
# 0          52.8%–76.0%
# 1          88.6%–93.9%

# %%
# Accuracy within PennText category
summarize_by_columns(manual_df, ['penntext'])
# Out:
#    penntext  n_articles  n_penntext_correct penntext_accuracy  \
# 0         0          78                  41             52.6%
# 1         1         422                 400             94.8%
#
#   penntext_accuracy_ci
# 0          41.6%–63.4%
# 1          92.4%–96.6%

# %%
# Accuracy within OA/Penn Access groups
summarize_by_columns(manual_df, ['open_access', 'penn_access'])
# Out:
#    open_access  penn_access  n_articles  n_penntext_correct penntext_accuracy  \
# 0            0            0          63                  41             65.1%
# 1            0            1         263                 249             94.7%
# 2            1            1         174                 151             86.8%
#
#   penntext_accuracy_ci
# 0          52.8%–76.0%
# 1          91.5%–96.9%
# 2          81.2%–91.2%

# %%
# Accuracy within OA/PennText groups
summarize_by_columns(manual_df, ['open_access', 'penntext'])
# Out:
#    open_access  penntext  n_articles  n_penntext_correct penntext_accuracy  \
# 0            0         0          55                  41             74.5%
# 1            0         1         271                 249             91.9%
# 2            1         0          23                   0              0.0%
# 3            1         1         151                 151            100.0%
#
#   penntext_accuracy_ci
# 0          62.0%–84.6%
# 1          88.2%–94.7%
# 2           0.0%–10.2%
# 3         98.4%–100.0%

# %%
# Accuracy within Penn Access/PennText groups
summarize_by_columns(manual_df, ['penn_access', 'penntext'])
# Out:
#    penn_access  penntext  n_articles  n_penntext_correct penntext_accuracy  \
# 0            0         0          41                  41            100.0%
# 1            0         1          22                   0              0.0%
# 2            1         0          37                   0              0.0%
# 3            1         1         400                 400            100.0%
#
#   penntext_accuracy_ci
# 0         94.1%–100.0%
# 1           0.0%–10.7%
# 2            0.0%–6.5%
# 3         99.4%–100.0%

# %%
# Accuracy by all possible contingencies
summarize_by_columns(manual_df, ['open_access', 'penn_access', 'penntext'])
# Out:
#    open_access  penn_access  penntext  n_articles  n_penntext_correct  \
# 0            0            0         0          41                  41
# 1            0            0         1          22                   0
# 2            0            1         0          14                   0
# 3            0            1         1         249                 249
# 4            1            1         0          23                   0
# 5            1            1         1         151                 151
#
#   penntext_accuracy penntext_accuracy_ci
# 0            100.0%         94.1%–100.0%
# 1              0.0%           0.0%–10.7%
# 2              0.0%           0.0%–16.2%
# 3            100.0%         99.0%–100.0%
# 4              0.0%           0.0%–10.2%
# 5            100.0%         98.4%–100.0%

# %% [markdown]
# ## DOIs with errors

# %%
# Penn does not have access, despite PennText claiming otherwise
manual_df.query("penn_access == 0 and penntext == 1")
# Out:
#                                         doi  penntext  penn_access  \
# 104              10.1109/chicc.2016.7554656         1            0
# 117           10.1080/09585192.2016.1242508         1            0
# 132               10.1109/tcyb.2016.2545688         1            0
# 147            10.1080/14754835.2014.923754         1            0
# 153            10.1080/01490419.2011.637154         1            0
# 172        10.1111/j.2044-8325.2012.02058.x         1            0
# 180                    10.1049/el.2015.0457         1            0
# 222              10.1109/jrproc.1955.277857         1            0
# 235                         10.2307/1882737         1            0
# 237             10.2174/0929867311320230002         1            0
# 252              10.1016/j.jcrs.2009.05.005         1            0
# 254                10.1109/lpt.2012.2202104         1            0
# 261  10.1061/(asce)0899-1561(2000)12:4(314)         1            0
# 263                         10.2307/3121146         1            0
# 288               10.1109/tnet.2013.2276063         1            0
# 290                   10.4065/mcp.2011.0128         1            0
# 304              10.1016/j.jhsa.2013.06.025         1            0
# 326         10.1109/isgteurope.2010.5638890         1            0
# 430            10.3109/19401736.2012.674125         1            0
# 463               10.1109/tasc.2011.2178847         1            0
# 481                 10.1126/science.1098148         1            0
# 483       10.3828/tpr.10.3.m23611542l2452v2         1            0
#
#      open_access penn_access_date open_access_date  penntext_correct
# 104            0       2018-01-03       2018-01-04                 0
# 117            0       2018-01-03       2018-01-04                 0
# 132            0       2018-01-03       2018-01-04                 0
# 147            0       2018-01-03       2018-01-04                 0
# 153            0       2018-01-03       2018-01-04                 0
# 172            0       2018-01-03       2018-01-04                 0
# 180            0       2018-01-12       2018-01-17                 0
# 222            0       2018-01-12       2018-01-17                 0
# 235            0       2018-01-12       2018-01-17                 0
# 237            0       2018-01-12       2018-01-17                 0
# 252            0       2018-01-12       2018-01-17                 0
# 254            0       2018-01-12       2018-01-17                 0
# 261            0       2018-01-12       2018-01-17                 0
# 263            0       2018-01-12       2018-01-17                 0
# 288            0       2018-01-16       2018-01-17                 0
# 290            0       2018-01-16       2018-01-19                 0
# 304            0       2018-01-16       2018-01-17                 0
# 326            0       2018-01-16       2018-01-17                 0
# 430            0       2018-01-16       2018-01-17                 0
# 463            0       2018-01-17       2018-01-17                 0
# 481            0       2018-01-17       2018-01-17                 0
# 483            0       2018-01-17       2018-01-17                 0

# %%
# Penn has subscription access that is unknown to PennText
manual_df.query("open_access == 0 and penn_access == 1 and penntext == 0")
# Out:
#                                    doi  penntext  penn_access  open_access  \
# 4   10.1111/j.1478-4408.1958.tb02258.x         0            1            0
# 5   10.1111/j.1550-7408.1962.tb02648.x         0            1            0
# 9               10.1136/bmj.1.4706.586         0            1            0
# 21      10.1002/14651858.cd008009.pub2         0            1            0
# 23            10.1002/prac.18430290165         0            1            0
# 26  10.1111/j.1468-5914.1986.tb00063.x         0            1            0
# 28        10.1097/ccm.0b013e31821b85c6         0            1            0
# 39           10.1007/s00261-016-0956-8         0            1            0
# 43           10.1107/s0108767388009286         0            1            0
# 46              10.1002/chin.197531174         0            1            0
# 47            10.1002/zaac.19402430401         0            1            0
# 58     10.1007/978-94-007-6173-5_139-1         0            1            0
# 63            10.1002/zamm.19660460319         0            1            0
# 65                10.1029/2000wr900383         0            1            0
#
#    penn_access_date open_access_date  penntext_correct
